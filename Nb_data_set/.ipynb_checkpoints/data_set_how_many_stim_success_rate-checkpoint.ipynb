# %%
import pandas as pd 
import numpy  as np 
from pathlib import Path
import pickle
import os

# %%
import data_set_analysis_helper_functions as ahf

# %%
#data to be analyzed: 
data_dir_input = "/Users/gilmandelbaum/Desktop/opto_final/OptoConsump"
#where to save the analyzed data: 
data_dir_output = "/Users/gilmandelbaum/Desktop/opto_final/OptoConsump_output_8"

Mouse_Date_FileName_list = "MasterOptoConsumption"


HowManyBack=1 

seq_str= "0a1ad2a4abc5a6b"

# %%
folder_name = "count_licks_perPeriod"

# %%
Mouse_Date_FileName = pd.read_csv(data_dir_input+"/"+Mouse_Date_FileName_list+".csv")

# %%
Mouse_Date_FileName
# Out:
#   Mouse    Date  D TypeOfStim SideOfStim
# 0  T183  190227  1          C          R
# 1  T183  190303  1          C          R
# 2  T183  190308  1          C          R
# 3  T183  190312  1          C          R
# 4  T183  190313  1          C          L
# 5  T183  190314  1          C          L
# 6  T183  190315  1          C          L
# 7  T183  190318  1          C          L
# 8  T183  190319  1          C          L

# %%
#Mouse_Date_FileName = Mouse_Date_FileName[Mouse_Date_FileName["Mouse"]=="T183"].reset_index()

# %%
dataSet = ahf.loadSession_pickle (Mouse_Date_FileName,data_dir_output,
                                  HowManyBack,folder_name,seq_str,"count_licks_perPeriod")

# %%
df = ahf.stimSuccessRate (dataSet,Mouse_Date_FileName)

# %%
df
# Out:
#   mouse      date    D SideOfStim  stimSwit  stimNoSwit  controlSwit  \
# 0  T183  190227.0  1.0          R       4.0         4.0          0.0
# 1  T183  190303.0  1.0          R       7.0         1.0          0.0
# 2  T183  190308.0  1.0          R       5.0         1.0          0.0
# 3  T183  190312.0  1.0          R       4.0         3.0          0.0
# 4  T183  190313.0  1.0          L       7.0         4.0          4.0
# 5  T183  190314.0  1.0          L      13.0         1.0          1.0
# 6  T183  190315.0  1.0          L      11.0         0.0          0.0
# 7  T183  190318.0  1.0          L       6.0         4.0          2.0
# 8  T183  190319.0  1.0          L       3.0         7.0          1.0
#
#    controlNoSwit
# 0            8.0
# 1            7.0
# 2            6.0
# 3            7.0
# 4            6.0
# 5           14.0
# 6           13.0
# 7            8.0
# 8           10.0

# %%
data_set = "data_set"+"_"+seq_str[:seq_str.index('6')]
cache_dir_plt = os.path.join(data_dir_output, data_set)
if not os.path.exists(cache_dir_plt):
    os.makedirs(cache_dir_plt)

# %%
file = "data_set_how_many_stim_success_rate"
cache_dir_plt = os.path.join(data_dir_output, data_set, file)
if not os.path.exists(cache_dir_plt):
    os.makedirs(cache_dir_plt)

# %%
df.to_csv(data_dir_output+"/"+data_set+"/"+file+"/"+"how_many_stim_success_rate"+seq_str+".csv")
